# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('automoble_buying_behavour.csv')

# %%
df.head(10)
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
# 5   28   Salaried         Married       Graduate                 3
# 6   31   Salaried         Married       Graduate                 4
# 7   33   Business         Married  Post Graduate                 4
# 8   34   Business         Married  Post Graduate                 4
# 9   34   Salaried         Married       Graduate                 3
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB

# %%
df.describe()
# Out:
#              Age  No of Dependents        Salary   Wife Salary  Total Salary  \
# count  99.000000         99.000000  9.900000e+01  9.900000e+01  9.900000e+01
# mean   36.313131          2.181818  1.736364e+06  5.343434e+05  2.270707e+06
# std     6.246054          1.335265  6.736217e+05  6.054450e+05  1.050777e+06
# min    26.000000          0.000000  2.000000e+05  0.000000e+00  2.000000e+05
# 25%    31.000000          2.000000  1.300000e+06  0.000000e+00  1.550000e+06
# 50%    36.000000          2.000000  1.600000e+06  5.000000e+05  2.100000e+06
# 75%    41.000000          3.000000  2.200000e+06  9.000000e+05  2.700000e+06
# max    51.000000          4.000000  3.800000e+06  2.100000e+06  5.200000e+06
#
#               Price
# count  9.900000e+01
# mean   1.194040e+06
# std    4.376955e+05
# min    1.100000e+05
# 25%    8.000000e+05
# 50%    1.200000e+06
# 75%    1.500000e+06
# max    3.000000e+06

# %%
df.dtypes
# Out:
# Age                  int64
# Profession          object
# Marrital Status     object
# Education           object
# No of Dependents     int64
# Personal loan       object
# House Loan          object
# Wife Working        object
# Salary               int64
# Wife Salary          int64
# Total Salary         int64
# Make                object
# Price                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                 0
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# Wife Working        0
# Salary              0
# Wife Salary         0
# Total Salary        0
# Make                0
# Price               0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Marrital Status', data=df)
plt.show()

# %%
df.drop(["Profession","Education","No of Dependents","Personal loan","House Loan","Wife Working","Wife Salary","Salary"], axis=1, inplace=True)

# %%
df
# Out:
#     Age Marrital Status  Total Salary    Make    Price
# 0    27          Single        800000     i20   800000
# 1    35         Married       2000000    Ciaz  1000000
# 2    45         Married       1800000  Duster  1200000
# 3    41         Married       2200000    City  1200000
# 4    31         Married       2600000     SUV  1600000
# ..  ...             ...           ...     ...      ...
# 94   27          Single       2400000     SUV  1600000
# 95   50         Married       5100000     SUV  1600000
# 96   51         Married       2200000    Ciaz  1100000
# 97   51         Married       4000000  Creata  1500000
# 98   51         Married       2200000    Ciaz  1100000
#
# [99 rows x 5 columns]

# %% [markdown]
# Encoding Single to 0 and Married to 1

# %%
df['Marrital Status'].replace(['Single', 'Married'], [0, 1], inplace=True)

# %%
df
# Out:
#     Age  Marrital Status  Total Salary    Make    Price
# 0    27                0        800000     i20   800000
# 1    35                1       2000000    Ciaz  1000000
# 2    45                1       1800000  Duster  1200000
# 3    41                1       2200000    City  1200000
# 4    31                1       2600000     SUV  1600000
# ..  ...              ...           ...     ...      ...
# 94   27                0       2400000     SUV  1600000
# 95   50                1       5100000     SUV  1600000
# 96   51                1       2200000    Ciaz  1100000
# 97   51                1       4000000  Creata  1500000
# 98   51                1       2200000    Ciaz  1100000
#
# [99 rows x 5 columns]

# %%
df["Make"].value_counts()
# Out:
# SUV        19
# Baleno     19
# Creata     14
# i20        12
# Ciaz       12
# City       10
# Duster      7
# Verna       4
# Luxuray     2
# Name: Make, dtype: int64

# %%
df["Price"].value_counts()
# Out:
# 1600000    18
# 700000     18
# 1500000    16
# 800000     13
# 1200000    13
# 1100000    12
# 1300000     5
# 3000000     2
# 1000000     1
# 110000      1
# Name: Price, dtype: int64

# %% [markdown]
# categorising Makes of cars into the Car Type with respective encoded values:
#
#     i20, Baleno :      Hatchback : 1
#     creta, Duster:     Crossover : 2
#     Ciaz, City, Verna: Sedan     : 3
#     SUV :              SUV       : 4
#     Luxuary:           Luxuary   : 5

# %%
df['Make'].replace(['i20', 'Baleno'], [1, 1], inplace=True)

# %%
df['Make'].replace(['Creata', 'Duster'], [2, 2], inplace=True)

# %%
df['Make'].replace(['Ciaz', 'City', 'Verna'], [3, 3, 3], inplace=True)

# %%
df['Make'].replace(['SUV'], [4], inplace=True)

# %%
df['Make'].replace(['Luxuray'], [5], inplace=True)

# %%
df
# Out:
#     Age  Marrital Status  Total Salary  Make    Price
# 0    27                0        800000     1   800000
# 1    35                1       2000000     3  1000000
# 2    45                1       1800000     2  1200000
# 3    41                1       2200000     3  1200000
# 4    31                1       2600000     4  1600000
# ..  ...              ...           ...   ...      ...
# 94   27                0       2400000     4  1600000
# 95   50                1       5100000     4  1600000
# 96   51                1       2200000     3  1100000
# 97   51                1       4000000     2  1500000
# 98   51                1       2200000     3  1100000
#
# [99 rows x 5 columns]

# %%
df.rename(columns={'Marrital Status': 'Marrital_Status', 'Total Salary': 'Salary'}, inplace=True)

# %%
df
# Out:
#     Age  Marrital_Status   Salary  Make    Price
# 0    27                0   800000     1   800000
# 1    35                1  2000000     3  1000000
# 2    45                1  1800000     2  1200000
# 3    41                1  2200000     3  1200000
# 4    31                1  2600000     4  1600000
# ..  ...              ...      ...   ...      ...
# 94   27                0  2400000     4  1600000
# 95   50                1  5100000     4  1600000
# 96   51                1  2200000     3  1100000
# 97   51                1  4000000     2  1500000
# 98   51                1  2200000     3  1100000
#
# [99 rows x 5 columns]

# %%
df["Make"].value_counts()
# Out:
# 1    31
# 3    26
# 2    21
# 4    19
# 5     2
# Name: Make, dtype: int64

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
plt.figure(1, figsize=(15,6))
n=0
for x in ['Age', 'Marrital_Status', 'Salary', 'Make', 'Price']:
    n+=1
    plt.subplot(1,5,n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.distplot(df[x], bins=20)
    plt.title('Density Plot of {}'.format(x))
plt.show()

# %%
df["Age"].value_counts()
# Out:
# 36    13
# 35    10
# 31     8
# 41     7
# 34     7
# 27     6
# 37     6
# 42     5
# 30     5
# 39     4
# 44     4
# 29     4
# 51     3
# 49     3
# 28     3
# 43     2
# 33     2
# 32     2
# 45     2
# 46     1
# 50     1
# 26     1
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Age', data=df)
plt.show()

# %%
age_26_30=df.Age[(df.Age>=26) & (df.Age<=30)]
age_31_35=df.Age[(df.Age>=31) & (df.Age<=35)]
age_36_40=df.Age[(df.Age>=36) & (df.Age<=40)]
age_41_45=df.Age[(df.Age>=41) & (df.Age<=45)]
age_46_50=df.Age[(df.Age>=46)& (df.Age<=50)]
age_50_above=df.Age[(df.Age>=51)]

agex=['26-30','31-35','36-40','41-45','46-50','50+']
agey=[len(age_26_30.values),len(age_31_35.values),len(age_36_40.values),len(age_41_45.values),len(age_46_50.values),len(age_50_above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=agex, y=agey, palette='mako')
plt.title("Number of Buyers and ages")
plt.xlabel('Age')
plt.ylabel('Number of Buyers')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Marrital_Status', data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Salary', data=df)

plt.show()

# %%
salary_2_10=df.Salary[(df.Salary>=200000) & (df.Salary<=1000000)]
salary_11_20=df.Salary[(df.Salary>=1100000) & (df.Salary<=2000000)]
salary_21_30=df.Salary[(df.Salary>=2100000) & (df.Salary<=3000000)]
salary_31_40=df.Salary[(df.Salary>=3100000) & (df.Salary<=4000000)]
salary_41_50=df.Salary[(df.Salary>=4100000) & (df.Salary<=5000000)]
salary_50above=df.Salary[(df.Salary>=5100000)]

salaryx=['2-10','11-20','21-30','31-44','41-50','50+']
salaryy=[len(salary_2_10.values),len(salary_11_20.values),len(salary_21_30.values),len(salary_31_40.values),len(salary_41_50.values),len(salary_50above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=salaryx, y=salaryy, palette='mako')
plt.title("Number of Buyers and Salaries")
plt.xlabel('Salary range in Lakh')
plt.ylabel('Number of Buyers')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Make', data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Price', data=df)
plt.show()

# %%
price_1_5=df.Price[(df.Price>=100000) & (df.Price<=500000)]
price_6_10=df.Price[(df.Price>=600000) & (df.Price<=1000000)]
price_11_15=df.Price[(df.Price>=1100000) & (df.Price<=1500000)]
price_16_20=df.Price[(df.Price>=1600000) & (df.Price<=2000000)]
price_21_25=df.Price[(df.Price>=2100000) & (df.Price<=2500000)]
price_26above=df.Price[(df.Price>=2600000)]

pricex=['1-5','6-10','11-15','16-20','21-25','26+']
pricey=[len(price_1_5.values),len(price_6_10.values),len(price_11_15.values),len(price_16_20.values),len(price_21_25.values),len(price_26above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=pricex, y=pricey, palette='mako')
plt.title("Frequency of Price Range")
plt.xlabel('Price range in Lakh')
plt.ylabel('Number of cars owned')
plt.show()

# %%
df.describe()
# Out:
#              Age  Marrital_Status        Salary       Make         Price
# count  99.000000        99.000000  9.900000e+01  99.000000  9.900000e+01
# mean   36.313131         0.848485  2.270707e+06   2.393939  1.194040e+06
# std     6.246054         0.360375  1.050777e+06   1.176454  4.376955e+05
# min    26.000000         0.000000  2.000000e+05   1.000000  1.100000e+05
# 25%    31.000000         1.000000  1.550000e+06   1.000000  8.000000e+05
# 50%    36.000000         1.000000  2.100000e+06   2.000000  1.200000e+06
# 75%    41.000000         1.000000  2.700000e+06   3.000000  1.500000e+06
# max    51.000000         1.000000  5.200000e+06   5.000000  3.000000e+06

# %%
matrix=df.corr()
print(matrix)
# Out:
#                       Age  Marrital_Status    Salary      Make     Price
# Age              1.000000         0.551688  0.587082  0.235776  0.376661
# Marrital_Status  0.551688         1.000000  0.416615  0.118153  0.149477
# Salary           0.587082         0.416615  1.000000  0.526984  0.717442
# Make             0.235776         0.118153  0.526984  1.000000  0.747922
# Price            0.376661         0.149477  0.717442  0.747922  1.000000

# %%
# Plot the heatmap
sns.heatmap(matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
sns.relplot(x='Age', y='Make', data=df)

# %%
sns.relplot(x='Age', y='Price', data=df)

# %%
sns.relplot(x='Marrital_Status', y='Make', data=df)

# %%
sns.relplot(x='Marrital_Status', y='Price', data=df)

# %%
sns.relplot(x='Salary', y='Make', data=df)

# %%
sns.relplot(x='Salary', y='Price', data=df)

# %%
sns.relplot(x='Price', y='Make', data=df)

# %%
# Clustring wrt salary and make

x1=df.loc[:, ['Salary','Make']].values
from sklearn.cluster import KMeans

wcss=[]

for k in range (1,11):
    kmeans=KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color='red', marker='8')
plt.xlabel('k values')
plt.ylabel('wcss')
plt.show()

# %%
K_Value=4

kmeans=KMeans(n_clusters=4)
label=kmeans.fit_predict(x1)
print(label)
# Out:
# [0 1 1 1 3 0 1 0 1 1 1 0 1 0 0 2 0 0 0 0 3 1 3 0 1 3 0 1 3 3 0 1 3 1 1 2 1
#  1 0 1 1 0 3 1 1 2 0 3 1 3 1 2 3 2 2 3 3 0 0 0 0 0 1 1 1 1 2 1 2 1 3 3 0 3
#  1 2 1 3 3 2 1 2 3 3 3 1 0 1 2 1 0 2 3 0 3 2 1 2 1]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[1.14400000e+06 1.56000000e+00]
#  [1.93888889e+06 2.22222222e+00]
#  [4.24000000e+06 3.20000000e+00]
#  [2.73043478e+06 3.04347826e+00]]

# %%
plt.scatter(x1[:,0], x1[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel('Salary')
plt.ylabel('Make')
plt.grid()

# %%
# Clustring wrt age and make

x1=df.loc[:, ['Price','Make']].values
from sklearn.cluster import KMeans

wcss=[]

for k in range (1,11):
    kmeans=KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color='red', marker='8')
plt.xlabel('k values')
plt.ylabel('wcss')
plt.show()

# %%
K_Value=4

kmeans=KMeans(n_clusters=4)
label=kmeans.fit_predict(x1)
print(label)
# Out:
# [0 3 3 3 1 0 3 0 3 0 1 0 0 0 0 2 0 0 3 0 3 0 1 0 3 1 0 0 3 1 0 3 1 1 3 1 3
#  1 1 3 0 3 1 3 0 1 3 3 0 1 3 1 1 1 2 1 3 0 3 0 3 1 1 0 3 0 1 3 1 3 1 1 0 1
#  3 1 0 1 1 1 0 1 3 3 0 0 0 3 1 0 0 1 3 0 1 1 3 1 3]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[7.22187500e+05 1.06250000e+00]
#  [1.55294118e+06 3.11764706e+00]
#  [3.00000000e+06 5.00000000e+00]
#  [1.17096774e+06 2.80645161e+00]]

# %%
plt.scatter(x1[:,0], x1[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel('Price')
plt.ylabel('Make')
plt.grid()

# %%
# Clustring wrt age and price

x1=df.loc[:, ['Age','Price']].values
from sklearn.cluster import KMeans

wcss=[]

for k in range (1,11):
    kmeans=KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color='red', marker='8')
plt.xlabel('k values')
plt.ylabel('wcss')
plt.show()

# %%
K_Value=4

kmeans=KMeans(n_clusters=4)
label=kmeans.fit_predict(x1)
print(label)
# Out:
# [1 3 3 3 0 1 3 1 3 1 0 1 1 1 1 2 1 1 3 1 3 1 0 1 3 0 1 1 3 0 1 3 0 0 3 0 3
#  0 0 3 1 3 0 3 1 0 3 3 1 0 3 0 0 0 2 0 3 1 3 1 3 0 0 1 3 1 0 3 0 3 0 0 1 0
#  3 0 1 0 0 0 1 0 3 3 1 1 1 3 0 1 1 0 3 1 0 0 3 0 3]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[3.79411765e+01 1.55294118e+06]
#  [3.33125000e+01 7.22187500e+05]
#  [4.50000000e+01 3.00000000e+06]
#  [3.70645161e+01 1.17096774e+06]]

# %%
plt.scatter(x1[:,0], x1[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel('Age')
plt.ylabel('Price')
plt.grid()

# %%
# Clustring wrt salary and price

x1=df.loc[:, ['Salary','Price']].values
from sklearn.cluster import KMeans

wcss=[]

for k in range (1,11):
    kmeans=KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color='red', marker='8')
plt.xlabel('k values')
plt.ylabel('wcss')
plt.show()

# %%
K_Value=4

kmeans=KMeans(n_clusters=3)
label=kmeans.fit_predict(x1)
print(label)
# Out:
# [0 2 0 2 2 0 0 0 2 0 2 0 0 0 0 1 0 0 0 0 2 0 2 0 2 2 0 0 2 2 0 2 2 2 2 1 0
#  2 0 2 0 0 2 2 0 1 0 2 0 2 2 1 2 1 1 2 2 0 0 0 0 0 2 0 2 0 1 2 1 0 2 2 0 2
#  2 1 0 2 2 1 2 1 2 2 2 0 0 2 1 0 0 1 2 0 2 1 2 1 2]

# %%
plt.scatter(x1[:,0], x1[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel('Salary')
plt.ylabel('Price')
plt.grid()

# %%
# Clustring wrt Age, salary and price

x3=df.loc[:, ['Age','Salary','Price']].values
from sklearn.cluster import KMeans

wcss=[]

for k in range (1,11):
    kmeans=KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(x3)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color='red', marker='8')
plt.xlabel('k values')
plt.ylabel('wcss')
plt.show()

# %%
kmeans=KMeans(n_clusters=4)
label=kmeans.fit_predict(x3)
print(label)
# Out:
# [1 3 3 3 0 1 3 1 3 3 3 1 1 1 1 2 1 1 1 1 0 3 0 1 3 0 1 1 0 0 1 3 0 3 3 2 3
#  3 3 3 3 1 0 3 1 2 1 0 1 0 3 2 0 2 2 0 0 1 1 1 1 3 3 3 3 1 2 3 2 3 0 0 1 0
#  3 2 3 0 0 2 3 2 3 0 0 3 1 3 2 3 1 2 0 1 0 2 3 2 3]

# %%
clusters=kmeans.fit_predict(x3)
df['label']=clusters

from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label==0], df['Salary'][df.label==0],df['Price'][df.label==0], c='blue', s=60)
ax.scatter(df.Age[df.label==1], df['Salary'][df.label==1],df['Price'][df.label==1], c='red', s=60)
ax.scatter(df.Age[df.label==2], df['Salary'][df.label==2],df['Price'][df.label==2], c='green', s=60)
ax.scatter(df.Age[df.label==3], df['Salary'][df.label==3],df['Price'][df.label==3], c='orange', s=60)

ax.view_init(30,185)

plt.xlabel('Age')
plt.ylabel('Salary')
plt.zlabel('Price')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 17
#      15 plt.xlabel('Age')
#      16 plt.ylabel('Salary')
# ---> 17 plt.zlabel('Price')
#      19 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'
